# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import glob
from scipy.stats import wilcoxon

# %%
import sys
sys.path.append('../General_functions/')
from plotting import global_palette
global_palette['Baseline'] = global_palette['linear']
global_palette['DEBIAS-M'] = global_palette['debias-m']

# %%
# %%time
result_paths = glob.glob('../../results/Simulations/all-simulation-runs/*.csv')
dfs = pd.concat( [ pd.read_csv(a, index_col=0) for a in result_paths ] )
# Out:
# CPU times: user 12 s, sys: 428 ms, total: 12.4 s
# Wall time: 13.6 s

# %%
dfs = dfs.loc[dfs.Pheno_noise > 0]
cols_of_interest = dfs.columns[2:-2]
default_vals = pd.DataFrame({'N_studies':4, 
                             'Pheno_noise':0.1, 
                             'Read_depth':1e5, 
                             'N_features':1e3, 
                             'N_per_study':96
                             }, 
                            index=[0]
                           )

# %%
cols_of_interest = dfs.columns[2:-2]

# %%
default_vals = pd.DataFrame({'N_studies':4, 
                             'Pheno_noise':0.1, 
                             'Read_depth':1e5, 
                             'N_features':1e3, 
                             'N_per_study':96
                             }, 
                            index=[0]
                           )
default_vals
# Out:
#    N_studies  Pheno_noise  Read_depth  N_features  N_per_study
# 0          4          0.1    100000.0      1000.0           96

# %%
for hide_axes in [False, True]:
    for col_of_interest in default_vals.columns:

        df_tmp = dfs.merge(default_vals.drop(col_of_interest, axis=1))

        df_tmp = df_tmp.groupby( list( df_tmp.columns.drop('JSD').values) 
                                   )['JSD'].median().reset_index()

        plt.figure(figsize=(12, 12))
        # plt.semilogy()
        ax=sns.boxplot(hue='Group', 
                    x = col_of_interest,
                    y = 'JSD', 
                    data=df_tmp, 
                    palette=global_palette,
                    fliersize=0)
        # plt.show()

        sns.stripplot(hue ='Group', 
                      x = col_of_interest,
                      y = 'JSD', 
                      data=df_tmp, 
                      color='black',
                      s=10, 
                      ax=ax, 
                      dodge=True
                      )




        q = pd.DataFrame( {'sig_v_debias':  [ wilcoxon( df_tmp.loc[( df_tmp[col_of_interest] == a)&
                                     ( df_tmp['Group'] == 'Baseline' )].JSD, 
                            df_tmp.loc[( df_tmp[col_of_interest] == a)&
                                       ( df_tmp['Group'] == 'DEBIAS-M' )].JSD, 
                                     alternative='greater'
                          ).pvalue < 1e-3
                           for a in df_tmp[col_of_interest].unique() ], 
                         col_of_interest:df_tmp[col_of_interest].unique(), 
                       'Group':['Baseline'] * df_tmp[col_of_interest].nunique()
                            }
                    )
        
        
        print(pd.DataFrame( {'sig_v_debias':  [ wilcoxon( df_tmp.loc[( df_tmp[col_of_interest] == a)&
                                     ( df_tmp['Group'] == 'Baseline' )].JSD, 
                            df_tmp.loc[( df_tmp[col_of_interest] == a)&
                                       ( df_tmp['Group'] == 'DEBIAS-M' )].JSD, 
                                     alternative='greater'
                          ).pvalue
                           for a in df_tmp[col_of_interest].unique() ], 
                         col_of_interest:df_tmp[col_of_interest].unique(), 
                       'Group':['Baseline'] * df_tmp[col_of_interest].nunique()
                            }
                    ))

        # q.columns = ['Group', 'sig_v_debias']
        q['lower_y_val'] = 0.19 # df_tmp.JSD.min() - 0.025

        if sum(q.sig_v_debias > 0):
            sns.swarmplot(
                          hue='Group', 
                          x=col_of_interest,
                          y='lower_y_val',
                          data = q.loc[q.sig_v_debias], 
        #                   hue_order = order,
        #                   order=order,
                          marker='+',
                          size=25/2, 
                          ax=ax,
                         palette=global_palette, 
                          dodge=True, 
                          color='black',
                          linewidth=3.5/2, 
                          )

            sns.swarmplot(hue='Group', 
                          x=col_of_interest,
                          y='lower_y_val',
                          data = q.loc[q.sig_v_debias], 
        #                   hue_order = order,
        #                   order=order,
                          marker='x',
                          size=17.5/2,
                          ax=ax,
                          palette=global_palette, 
                          dodge=True, 
                          color='black',
                          linewidth=3.5/2,
                          edgecolor="black", 
                          )

        plt.ylabel('JSD')
        plt.legend().remove()
        plt.ylim(0, 0.2)
        ax.set(yticks=np.linspace(0, 0.2, 5),
              )
        
        out_path = '../../results/Simulations/JSD-plot-{}.pdf'.format(col_of_interest)
        if hide_axes:
            ax.set_xticks([])
            ax.set(yticks=np.linspace(0, 0.2, 5),
                   yticklabels=[])
            plt.xlabel(None)
            plt.ylabel(None)
            plt.title(None)
            plt.savefig(out_path[:-4] + '-no-axes'+out_path[-4:], 
                        dpi=900,
                        bbox_inches='tight', 
                        format='pdf')

        else:
            plt.savefig(out_path, 
                        dpi=900,
                       bbox_inches='tight', 
                       format='pdf')
# Out:
#    sig_v_debias  N_studies     Group
# 0  4.401803e-05          2  Baseline
# 1  4.172325e-07          3  Baseline
# 2  5.662441e-07          4  Baseline
#    sig_v_debias  Pheno_noise     Group
# 0  5.662441e-07          0.1  Baseline
# 1  2.980232e-08          1.0  Baseline
# 2  2.980232e-08         10.0  Baseline
#    sig_v_debias  Read_depth     Group
# 0  2.622604e-06      1000.0  Baseline
# 1  1.332164e-05     10000.0  Baseline
# 2  5.662441e-07    100000.0  Baseline
#    sig_v_debias  N_features     Group
# 0  7.629395e-06         100  Baseline
# 1  5.662441e-07        1000  Baseline
#    sig_v_debias  N_per_study     Group
# 0  8.940697e-08           24  Baseline
# 1  2.980232e-08           48  Baseline
# 2  2.980232e-08           72  Baseline
# 3  5.662441e-07           96  Baseline
#    sig_v_debias  N_studies     Group
# 0  4.401803e-05          2  Baseline
# 1  4.172325e-07          3  Baseline
# 2  5.662441e-07          4  Baseline
#    sig_v_debias  Pheno_noise     Group
# 0  5.662441e-07          0.1  Baseline
# 1  2.980232e-08          1.0  Baseline
# 2  2.980232e-08         10.0  Baseline
#    sig_v_debias  Read_depth     Group
# 0  2.622604e-06      1000.0  Baseline
# 1  1.332164e-05     10000.0  Baseline
# 2  5.662441e-07    100000.0  Baseline
#    sig_v_debias  N_features     Group
# 0  7.629395e-06         100  Baseline
# 1  5.662441e-07        1000  Baseline
#    sig_v_debias  N_per_study     Group
# 0  8.940697e-08           24  Baseline
# 1  2.980232e-08           48  Baseline
# 2  2.980232e-08           72  Baseline
# 3  5.662441e-07           96  Baseline

# %%
# import statannot

# %%
for hide_axes in [False, True]:
    for col_of_interest in default_vals.columns:
        break
        
        
df_tmp = dfs.merge(default_vals.drop(col_of_interest, axis=1))

df_tmp = df_tmp.groupby( list( df_tmp.columns.drop('JSD').values) 
                           )['JSD'].median().reset_index()

plt.figure(figsize=(12, 12))
# plt.semilogy()
ax=sns.boxplot(hue='Group', 
            x = col_of_interest,
            y = 'JSD', 
            data=df_tmp, 
            palette=global_palette,
            fliersize=0)
# plt.show()

sns.stripplot(hue ='Group', 
              x = col_of_interest,
              y = 'JSD', 
              data=df_tmp, 
              color='black',
              s=10, 
              ax=ax, 
              dodge=True
              )

plt.ylabel('JSD')
plt.legend().remove()
plt.ylim(0, 0.2)
ax.set(yticks=np.linspace(0, 0.2, 5),
      )

statannot.add_stat_annotation(
    ax,
    data=df_tmp,
    x=col_of_interest,
    y='JSD',
    hue='Group',
    box_pairs=[((a, 'Baseline'), (a, 'DEBIAS-M'))
                for a in df_tmp[col_of_interest].unique()],
    test="Wilcoxon",
    text_format="star",
#     loc="outside",
)
annot.apply_test().annotate(line_offset_to_group=0.2, line_offset=0.1)

plt.show()
# Out:
# p-value annotation legend:
# ns: 5.00e-02 < p <= 1.00e+00
# *: 1.00e-02 < p <= 5.00e-02
# **: 1.00e-03 < p <= 1.00e-02
# ***: 1.00e-04 < p <= 1.00e-03
# ****: p <= 1.00e-04
#
# Using zero_method  wilcox
# 3_Baseline v.s. 3_DEBIAS-M: Wilcoxon test (paired samples) with Bonferroni correction, P_val=2.503e-06 stat=6.000e+00
# Using zero_method  wilcox
# 2_Baseline v.s. 2_DEBIAS-M: Wilcoxon test (paired samples) with Bonferroni correction, P_val=2.641e-04 stat=2.800e+01
# Using zero_method  wilcox
# 4_Baseline v.s. 4_DEBIAS-M: Wilcoxon test (paired samples) with Bonferroni correction, P_val=3.397e-06 stat=7.000e+00

# %%
import statannot
statannot.add_stat_annotation(
    ax,
    data=df,
    x=x,
    y=y,
    hue=hue,
    box_pairs=[
        (("Biscoe", "Male"), ("Torgersen", "Female")),
        (("Dream", "Male"), ("Dream", "Female")),
    ],
    test="t-test_ind",
    text_format="star",
    loc="outside",
)
