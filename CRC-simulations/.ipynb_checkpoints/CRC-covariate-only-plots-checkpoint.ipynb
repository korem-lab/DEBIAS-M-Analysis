# %%
import numpy as np
import pandas as pd

# %%
import sys
sys.path.append('../v1-DEBIAS-M-Analysis/General_functions/')
from plotting import produce_auroc_boxplot

# %%
plot_data = pd.read_csv('../results/CRC_with_labels/auroc-boxplot-linear.csv', 
                        index_col=0)

plot_data=plot_data.loc[plot_data.Group.isin(['conqur', 'percnorm', 'snm'])]

produce_auroc_boxplot(plot_data, 
    out_path='../results/CRC_with_labels/fewer-methods-auroc-boxplot-linear.pdf', 
                     order=['conqur', 'snm', 'percnorm'], 
                     hide_axes=False)

produce_auroc_boxplot(plot_data, 
    out_path='../results/CRC_with_labels/fewer-methods-auroc-boxplot-linear.pdf', 
                     order=['conqur', 'snm', 'percnorm'])
# Out:
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.

# %%
plot_data = pd.read_csv('../results/CRC_with_labels/auroc-clr-boxplot-linear.csv', 
                        index_col=0)

plot_data=plot_data.loc[plot_data.Group.isin(['conqur', 'percnorm'])]

produce_auroc_boxplot(plot_data, 
    out_path='../results/CRC_with_labels/fewer-methods-auroc-clr-boxplot-linear.pdf', 
                     order=['conqur',  'percnorm'], 
                     hide_axes=False)

produce_auroc_boxplot(plot_data, 
    out_path='../results/CRC_with_labels/fewer-methods-auroc-clr-boxplot-linear.pdf', 
                     order=['conqur', 'percnorm'])
# Out:
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
