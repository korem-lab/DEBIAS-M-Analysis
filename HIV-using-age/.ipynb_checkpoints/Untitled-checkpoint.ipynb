# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import sys
sys.path.append('../v1-DEBIAS-M-Analysis/General_functions/')
import plotting
from plotting import global_palette
import matplotlib.ticker as ticker
import data_loading

# %%
# !ls tmp-datasets-for-R/
# Out:
# MMUPHin_out.csv    combat-out.csv     data.csv           percnorm_out.csv
# PLSDAbatch_out.csv conqur-out.csv     md.csv             voom-snm-out.csv

# %%
df, md = data_loading.load_HIVRC('../data/HIVRC/')
df_with_batch = pd.concat([pd.Series( pd.Categorical(md.Study).codes, 
                                         index=md.index), df], axis=1) 
df_conqur = pd.read_csv('tmp-datasets-for-R/conqur-out.csv', index_col=0)
df_combat =  pd.read_csv('tmp-datasets-for-R/combat-out.csv', index_col=0)
df_snm = pd.read_csv('tmp-datasets-for-R/voom-snm-out.csv', index_col=0)
df_mup =  pd.read_csv('tmp-datasets-for-R/MMUPHin_out.csv', index_col=0)
df_pls = pd.read_csv('tmp-datasets-for-R/PLSDAbatch_out.csv', index_col=0)
df_perc =  pd.read_csv('tmp-datasets-for-R/percnorm_out.csv', index_col=0)
df_combat.index = df_conqur.index
df_snm.index = df_conqur.index

# %%
def batch_weight_feature_and_nbatchpairs_scaling(strength, df_with_batch):
    nbs = df_with_batch.iloc[:, 0].nunique()
    w = nbs * (nbs - 1) / 2
    return(strength /( w * ( df_with_batch.shape[1] - 1 ) ) )

# %%
sys.path.append('../v1-DEBIAS-M-Analysis')

# %%
from all_classification_pipelines import run_predictions
v_out =  run_predictions(md.label, 
                         df_with_batch, 
                         df_conqur, 
                         df_combat, 
                         seed=123, 
                         do_clr_transform=False,
                         b_str=batch_weight_feature_and_nbatchpairs_scaling(1e4, df_with_batch),
                         df_snm=df_snm, 
                         df_mup=df_mup, 
                         df_pls=df_pls, 
                         df_perc=df_perc.fillna(1e-6)
                         )
# Out:
# /Users/george/opt/anaconda3/envs/pl2/lib/python3.6/site-packages/pytorch_lightning/trainer/connectors/callback_connector.py:168: LightningDeprecationWarning: Setting `Trainer(weights_summary=None)` is deprecated in v1.5 and will be removed in v1.7. Please set `Trainer(enable_model_summary=False)` instead.
#   "Setting `Trainer(weights_summary=None)` is deprecated in v1.5 and will be removed"
# GPU available: False, used: False
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# (1032, 780)
# [] [] [] [] [] [] [] []
# Validation sanity check: 0it [00:00, ?it/s]
# /Users/george/opt/anaconda3/envs/pl2/lib/python3.6/site-packages/pytorch_lightning/trainer/data_loading.py:133: UserWarning: The dataloader, val_dataloader 0, does not have many workers which may be a bottleneck. Consider increasing the value of the `num_workers` argument` (try 8 which is the number of cpus on this machine) in the `DataLoader` init to improve performance.
#   f"The dataloader, {name}, does not have many workers which may be a bottleneck."
# /Users/george/opt/anaconda3/envs/pl2/lib/python3.6/site-packages/SBCMP/__init__.py:78: UserWarning: Implicit dimension choice for softmax has been deprecated. Change the call to include dim=X as an argument.
#   y_hat = softmax(x)
# /Users/george/opt/anaconda3/envs/pl2/lib/python3.6/site-packages/pytorch_lightning/trainer/data_loading.py:133: UserWarning: The dataloader, train_dataloader, does not have many workers which may be a bottleneck. Consider increasing the value of the `num_workers` argument` (try 8 which is the number of cpus on this machine) in the `DataLoader` init to improve performance.
#   f"The dataloader, {name}, does not have many workers which may be a bottleneck."
# Training: 0it [00:00, ?it/s]
# Validating: 0it [00:00, ?it/s]
# Validating: 0it [00:00, ?it/s]
# Validating: 0it [00:00, ?it/s]
# Validating: 0it [00:00, ?it/s]
# Validating: 0it [00:00, ?it/s]
# Validating: 0it [00:00, ?it/s]
# Validating: 0it [00:00, ?it/s]
# Validating: 0it [00:00, ?it/s]
# Validating: 0it [00:00, ?it/s]
# Validating: 0it [00:00, ?it/s]
# Validating: 0it [00:00, ?it/s]
# Validating: 0it [00:00, ?it/s]
# Validating: 0it [00:00, ?it/s]
# Validating: 0it [00:00, ?it/s]
# Validating: 0it [00:00, ?it/s]
# Validating: 0it [00:00, ?it/s]
# Validating: 0it [00:00, ?it/s]
# Validating: 0it [00:00, ?it/s]
# Validating: 0it [00:00, ?it/s]
# Validating: 0it [00:00, ?it/s]
# Validating: 0it [00:00, ?it/s]
# /Users/george/opt/anaconda3/envs/pl2/lib/python3.6/site-packages/SBCMP/__init__.py:25: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   return(xx/xx.sum(axis=1)[:, np.newaxis] )
# /Users/george/opt/anaconda3/envs/pl2/lib/python3.6/site-packages/SBCMP/__init__.py:25: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   return(xx/xx.sum(axis=1)[:, np.newaxis] )
# [0.5267249757045676] [0.631681243926142] [0.5267249757045677] [0.5174927113702624] [0.48833819241982507] [0.5578231292517006] [0.5053449951409135] [0.5218658892128281]
# [0.5267249757045676] [0.631681243926142] [0.5267249757045677] [0.5174927113702624] [0.48833819241982507] [0.5578231292517006] [0.5053449951409135] [0.5218658892128281]
# /Users/george/opt/anaconda3/envs/pl2/lib/python3.6/site-packages/pytorch_lightning/trainer/connectors/callback_connector.py:168: LightningDeprecationWarning: Setting `Trainer(weights_summary=None)` is deprecated in v1.5 and will be removed in v1.7. Please set `Trainer(enable_model_summary=False)` instead.
#   "Setting `Trainer(weights_summary=None)` is deprecated in v1.5 and will be removed"
# GPU available: False, used: False
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# Validation sanity check: 0it [00:00, ?it/s]
# /Users/george/opt/anaconda3/envs/pl2/lib/python3.6/site-packages/pytorch_lightning/trainer/data_loading.py:133: UserWarning: The dataloader, val_dataloader 0, does not have many workers which may be a bottleneck. Consider increasing the value of the `num_workers` argument` (try 8 which is the number of cpus on this machine) in the `DataLoader` init to improve performance.
#   f"The dataloader, {name}, does not have many workers which may be a bottleneck."
# /Users/george/opt/anaconda3/envs/pl2/lib/python3.6/site-packages/SBCMP/__init__.py:78: UserWarning: Implicit dimension choice for softmax has been deprecated. Change the call to include dim=X as an argument.
#   y_hat = softmax(x)
# /Users/george/opt/anaconda3/envs/pl2/lib/python3.6/site-packages/pytorch_lightning/trainer/data_loading.py:133: UserWarning: The dataloader, train_dataloader, does not have many workers which may be a bottleneck. Consider increasing the value of the `num_workers` argument` (try 8 which is the number of cpus on this machine) in the `DataLoader` init to improve performance.
#   f"The dataloader, {name}, does not have many workers which may be a bottleneck."
# Training: 0it [00:00, ?it/s]
# Validating: 0it [00:00, ?it/s]
# Validating: 0it [00:00, ?it/s]
# Validating: 0it [00:00, ?it/s]
# Trainer was signaled to stop but required minimum epochs (25) or minimum steps (None) has not been met. Training will continue...
# Validating: 0it [00:00, ?it/s]
# Trainer was signaled to stop but required minimum epochs (25) or minimum steps (None) has not been met. Training will continue...
# Validating: 0it [00:00, ?it/s]
# Trainer was signaled to stop but required minimum epochs (25) or minimum steps (None) has not been met. Training will continue...
# Validating: 0it [00:00, ?it/s]
# Trainer was signaled to stop but required minimum epochs (25) or minimum steps (None) has not been met. Training will continue...
# Validating: 0it [00:00, ?it/s]
# Validating: 0it [00:00, ?it/s]
# Validating: 0it [00:00, ?it/s]
# Validating: 0it [00:00, ?it/s]
# Validating: 0it [00:00, ?it/s]
# Validating: 0it [00:00, ?it/s]
# Validating: 0it [00:00, ?it/s]
# Validating: 0it [00:00, ?it/s]
# Validating: 0it [00:00, ?it/s]
# Validating: 0it [00:00, ?it/s]
# Validating: 0it [00:00, ?it/s]
# Validating: 0it [00:00, ?it/s]
# Validating: 0it [00:00, ?it/s]
# Validating: 0it [00:00, ?it/s]
# Validating: 0it [00:00, ?it/s]
# Validating: 0it [00:00, ?it/s]
# Validating: 0it [00:00, ?it/s]
# Validating: 0it [00:00, ?it/s]
# Validating: 0it [00:00, ?it/s]
# Validating: 0it [00:00, ?it/s]
# Validating: 0it [00:00, ?it/s]
# Validating: 0it [00:00, ?it/s]
# Validating: 0it [00:00, ?it/s]
# Validating: 0it [00:00, ?it/s]
# Validating: 0it [00:00, ?it/s]
# /Users/george/opt/anaconda3/envs/pl2/lib/python3.6/site-packages/SBCMP/__init__.py:25: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   return(xx/xx.sum(axis=1)[:, np.newaxis] )
# /Users/george/opt/anaconda3/envs/pl2/lib/python3.6/site-packages/SBCMP/__init__.py:25: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   return(xx/xx.sum(axis=1)[:, np.newaxis] )
# /Users/george/opt/anaconda3/envs/pl2/lib/python3.6/site-packages/pytorch_lightning/trainer/connectors/callback_connector.py:168: LightningDeprecationWarning: Setting `Trainer(weights_summary=None)` is deprecated in v1.5 and will be removed in v1.7. Please set `Trainer(enable_model_summary=False)` instead.
#   "Setting `Trainer(weights_summary=None)` is deprecated in v1.5 and will be removed"
# GPU available: False, used: False
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# [0.5267249757045676, 0.3135483870967742] [0.631681243926142, 0.6864516129032258] [0.5267249757045677, 0.6154838709677419] [0.5174927113702624, 0.5393548387096774] [0.48833819241982507, 0.7625806451612903] [0.5578231292517006, 0.47870967741935483] [0.5053449951409135, 0.35161290322580646] [0.5218658892128281, 0.664516129032258]
# Validation sanity check: 0it [00:00, ?it/s]
# /Users/george/opt/anaconda3/envs/pl2/lib/python3.6/site-packages/pytorch_lightning/trainer/data_loading.py:133: UserWarning: The dataloader, val_dataloader 0, does not have many workers which may be a bottleneck. Consider increasing the value of the `num_workers` argument` (try 8 which is the number of cpus on this machine) in the `DataLoader` init to improve performance.
#   f"The dataloader, {name}, does not have many workers which may be a bottleneck."
# /Users/george/opt/anaconda3/envs/pl2/lib/python3.6/site-packages/SBCMP/__init__.py:78: UserWarning: Implicit dimension choice for softmax has been deprecated. Change the call to include dim=X as an argument.
#   y_hat = softmax(x)
# /Users/george/opt/anaconda3/envs/pl2/lib/python3.6/site-packages/pytorch_lightning/trainer/data_loading.py:133: UserWarning: The dataloader, train_dataloader, does not have many workers which may be a bottleneck. Consider increasing the value of the `num_workers` argument` (try 8 which is the number of cpus on this machine) in the `DataLoader` init to improve performance.
#   f"The dataloader, {name}, does not have many workers which may be a bottleneck."
# Training: 0it [00:00, ?it/s]
# Validating: 0it [00:00, ?it/s]
# Validating: 0it [00:00, ?it/s]
# Validating: 0it [00:00, ?it/s]
# Validating: 0it [00:00, ?it/s]
# Validating: 0it [00:00, ?it/s]
# Validating: 0it [00:00, ?it/s]
# Validating: 0it [00:00, ?it/s]
# Trainer was signaled to stop but required minimum epochs (25) or minimum steps (None) has not been met. Training will continue...
# Validating: 0it [00:00, ?it/s]
# Trainer was signaled to stop but required minimum epochs (25) or minimum steps (None) has not been met. Training will continue...
# Validating: 0it [00:00, ?it/s]
# Trainer was signaled to stop but required minimum epochs (25) or minimum steps (None) has not been met. Training will continue...
# Validating: 0it [00:00, ?it/s]
# Trainer was signaled to stop but required minimum epochs (25) or minimum steps (None) has not been met. Training will continue...
# Validating: 0it [00:00, ?it/s]
# Trainer was signaled to stop but required minimum epochs (25) or minimum steps (None) has not been met. Training will continue...
# Validating: 0it [00:00, ?it/s]
# Trainer was signaled to stop but required minimum epochs (25) or minimum steps (None) has not been met. Training will continue...
# Validating: 0it [00:00, ?it/s]
# /Users/george/opt/anaconda3/envs/pl2/lib/python3.6/site-packages/SBCMP/__init__.py:25: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   return(xx/xx.sum(axis=1)[:, np.newaxis] )
# /Users/george/opt/anaconda3/envs/pl2/lib/python3.6/site-packages/SBCMP/__init__.py:25: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   return(xx/xx.sum(axis=1)[:, np.newaxis] )
# /Users/george/opt/anaconda3/envs/pl2/lib/python3.6/site-packages/pytorch_lightning/trainer/connectors/callback_connector.py:168: LightningDeprecationWarning: Setting `Trainer(weights_summary=None)` is deprecated in v1.5 and will be removed in v1.7. Please set `Trainer(enable_model_summary=False)` instead.
#   "Setting `Trainer(weights_summary=None)` is deprecated in v1.5 and will be removed"
# GPU available: False, used: False
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# [0.5267249757045676, 0.3135483870967742, 0.44235588972431084] [0.631681243926142, 0.6864516129032258, 0.8646616541353384] [0.5267249757045677, 0.6154838709677419, 0.5087719298245613] [0.5174927113702624, 0.5393548387096774, 0.6303258145363408] [0.48833819241982507, 0.7625806451612903, 0.7268170426065164] [0.5578231292517006, 0.47870967741935483, 0.6027568922305764] [0.5053449951409135, 0.35161290322580646, 0.41102756892230574] [0.5218658892128281, 0.664516129032258, 0.5]
# Validation sanity check: 0it [00:00, ?it/s]
# /Users/george/opt/anaconda3/envs/pl2/lib/python3.6/site-packages/pytorch_lightning/trainer/data_loading.py:133: UserWarning: The dataloader, val_dataloader 0, does not have many workers which may be a bottleneck. Consider increasing the value of the `num_workers` argument` (try 8 which is the number of cpus on this machine) in the `DataLoader` init to improve performance.
#   f"The dataloader, {name}, does not have many workers which may be a bottleneck."
# /Users/george/opt/anaconda3/envs/pl2/lib/python3.6/site-packages/SBCMP/__init__.py:78: UserWarning: Implicit dimension choice for softmax has been deprecated. Change the call to include dim=X as an argument.
#   y_hat = softmax(x)
# /Users/george/opt/anaconda3/envs/pl2/lib/python3.6/site-packages/pytorch_lightning/trainer/data_loading.py:133: UserWarning: The dataloader, train_dataloader, does not have many workers which may be a bottleneck. Consider increasing the value of the `num_workers` argument` (try 8 which is the number of cpus on this machine) in the `DataLoader` init to improve performance.
#   f"The dataloader, {name}, does not have many workers which may be a bottleneck."
# Training: 0it [00:00, ?it/s]
# Validating: 0it [00:00, ?it/s]
# Validating: 0it [00:00, ?it/s]
# Validating: 0it [00:00, ?it/s]
# Validating: 0it [00:00, ?it/s]
# Validating: 0it [00:00, ?it/s]
# Validating: 0it [00:00, ?it/s]
# Validating: 0it [00:00, ?it/s]
# Validating: 0it [00:00, ?it/s]
# Validating: 0it [00:00, ?it/s]
# Validating: 0it [00:00, ?it/s]
# Validating: 0it [00:00, ?it/s]
# Validating: 0it [00:00, ?it/s]
# Validating: 0it [00:00, ?it/s]
# Validating: 0it [00:00, ?it/s]
# Validating: 0it [00:00, ?it/s]
# Validating: 0it [00:00, ?it/s]
# Validating: 0it [00:00, ?it/s]
# Validating: 0it [00:00, ?it/s]
# Validating: 0it [00:00, ?it/s]
# /Users/george/opt/anaconda3/envs/pl2/lib/python3.6/site-packages/SBCMP/__init__.py:25: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   return(xx/xx.sum(axis=1)[:, np.newaxis] )
# /Users/george/opt/anaconda3/envs/pl2/lib/python3.6/site-packages/SBCMP/__init__.py:25: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   return(xx/xx.sum(axis=1)[:, np.newaxis] )
# /Users/george/opt/anaconda3/envs/pl2/lib/python3.6/site-packages/pytorch_lightning/trainer/connectors/callback_connector.py:168: LightningDeprecationWarning: Setting `Trainer(weights_summary=None)` is deprecated in v1.5 and will be removed in v1.7. Please set `Trainer(enable_model_summary=False)` instead.
#   "Setting `Trainer(weights_summary=None)` is deprecated in v1.5 and will be removed"
# GPU available: False, used: False
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# [0.5267249757045676, 0.3135483870967742, 0.44235588972431084, 0.3365384615384615] [0.631681243926142, 0.6864516129032258, 0.8646616541353384, 0.7307692307692307] [0.5267249757045677, 0.6154838709677419, 0.5087719298245613, 0.5705128205128205] [0.5174927113702624, 0.5393548387096774, 0.6303258145363408, 0.5785256410256411] [0.48833819241982507, 0.7625806451612903, 0.7268170426065164, 0.6025641025641025] [0.5578231292517006, 0.47870967741935483, 0.6027568922305764, 0.43269230769230765] [0.5053449951409135, 0.35161290322580646, 0.41102756892230574, 0.35256410256410253] [0.5218658892128281, 0.664516129032258, 0.5, 0.5304487179487178]
# Validation sanity check: 0it [00:00, ?it/s]
# /Users/george/opt/anaconda3/envs/pl2/lib/python3.6/site-packages/pytorch_lightning/trainer/data_loading.py:133: UserWarning: The dataloader, val_dataloader 0, does not have many workers which may be a bottleneck. Consider increasing the value of the `num_workers` argument` (try 8 which is the number of cpus on this machine) in the `DataLoader` init to improve performance.
#   f"The dataloader, {name}, does not have many workers which may be a bottleneck."
# /Users/george/opt/anaconda3/envs/pl2/lib/python3.6/site-packages/SBCMP/__init__.py:78: UserWarning: Implicit dimension choice for softmax has been deprecated. Change the call to include dim=X as an argument.
#   y_hat = softmax(x)
# /Users/george/opt/anaconda3/envs/pl2/lib/python3.6/site-packages/pytorch_lightning/trainer/data_loading.py:133: UserWarning: The dataloader, train_dataloader, does not have many workers which may be a bottleneck. Consider increasing the value of the `num_workers` argument` (try 8 which is the number of cpus on this machine) in the `DataLoader` init to improve performance.
#   f"The dataloader, {name}, does not have many workers which may be a bottleneck."
# Training: 0it [00:00, ?it/s]
# Validating: 0it [00:00, ?it/s]
# Validating: 0it [00:00, ?it/s]
# Validating: 0it [00:00, ?it/s]
# Validating: 0it [00:00, ?it/s]
# Validating: 0it [00:00, ?it/s]
# Validating: 0it [00:00, ?it/s]
# Validating: 0it [00:00, ?it/s]
# Validating: 0it [00:00, ?it/s]
# Validating: 0it [00:00, ?it/s]
# Validating: 0it [00:00, ?it/s]
# Validating: 0it [00:00, ?it/s]
# Validating: 0it [00:00, ?it/s]
# Trainer was signaled to stop but required minimum epochs (25) or minimum steps (None) has not been met. Training will continue...
# Validating: 0it [00:00, ?it/s]
# /Users/george/opt/anaconda3/envs/pl2/lib/python3.6/site-packages/SBCMP/__init__.py:25: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   return(xx/xx.sum(axis=1)[:, np.newaxis] )
# /Users/george/opt/anaconda3/envs/pl2/lib/python3.6/site-packages/SBCMP/__init__.py:25: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   return(xx/xx.sum(axis=1)[:, np.newaxis] )
# [0.5267249757045676, 0.3135483870967742, 0.44235588972431084, 0.3365384615384615, 0.4666666666666667] [0.631681243926142, 0.6864516129032258, 0.8646616541353384, 0.7307692307692307, 0.8407407407407407] [0.5267249757045677, 0.6154838709677419, 0.5087719298245613, 0.5705128205128205, 0.7518518518518519] [0.5174927113702624, 0.5393548387096774, 0.6303258145363408, 0.5785256410256411, 0.45925925925925926] [0.48833819241982507, 0.7625806451612903, 0.7268170426065164, 0.6025641025641025, 0.5518518518518519] [0.5578231292517006, 0.47870967741935483, 0.6027568922305764, 0.43269230769230765, 0.5703703703703704] [0.5053449951409135, 0.35161290322580646, 0.41102756892230574, 0.35256410256410253, 0.6388888888888888] [0.5218658892128281, 0.664516129032258, 0.5, 0.5304487179487178, 0.7851851851851852]
# /Users/george/opt/anaconda3/envs/pl2/lib/python3.6/site-packages/pytorch_lightning/trainer/connectors/callback_connector.py:168: LightningDeprecationWarning: Setting `Trainer(weights_summary=None)` is deprecated in v1.5 and will be removed in v1.7. Please set `Trainer(enable_model_summary=False)` instead.
#   "Setting `Trainer(weights_summary=None)` is deprecated in v1.5 and will be removed"
# GPU available: False, used: False
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# Validation sanity check: 0it [00:00, ?it/s]
# /Users/george/opt/anaconda3/envs/pl2/lib/python3.6/site-packages/pytorch_lightning/trainer/data_loading.py:133: UserWarning: The dataloader, val_dataloader 0, does not have many workers which may be a bottleneck. Consider increasing the value of the `num_workers` argument` (try 8 which is the number of cpus on this machine) in the `DataLoader` init to improve performance.
#   f"The dataloader, {name}, does not have many workers which may be a bottleneck."
# /Users/george/opt/anaconda3/envs/pl2/lib/python3.6/site-packages/SBCMP/__init__.py:78: UserWarning: Implicit dimension choice for softmax has been deprecated. Change the call to include dim=X as an argument.
#   y_hat = softmax(x)
# /Users/george/opt/anaconda3/envs/pl2/lib/python3.6/site-packages/pytorch_lightning/trainer/data_loading.py:133: UserWarning: The dataloader, train_dataloader, does not have many workers which may be a bottleneck. Consider increasing the value of the `num_workers` argument` (try 8 which is the number of cpus on this machine) in the `DataLoader` init to improve performance.
#   f"The dataloader, {name}, does not have many workers which may be a bottleneck."
# Training: 0it [00:00, ?it/s]
# Validating: 0it [00:00, ?it/s]
# Validating: 0it [00:00, ?it/s]
# Validating: 0it [00:00, ?it/s]
# Validating: 0it [00:00, ?it/s]
# Validating: 0it [00:00, ?it/s]
# Validating: 0it [00:00, ?it/s]
# Validating: 0it [00:00, ?it/s]
# Validating: 0it [00:00, ?it/s]
# Validating: 0it [00:00, ?it/s]
# Validating: 0it [00:00, ?it/s]
# Validating: 0it [00:00, ?it/s]
# Validating: 0it [00:00, ?it/s]
# Validating: 0it [00:00, ?it/s]
# Validating: 0it [00:00, ?it/s]
# Validating: 0it [00:00, ?it/s]
# Validating: 0it [00:00, ?it/s]
# Validating: 0it [00:00, ?it/s]
# Validating: 0it [00:00, ?it/s]
# Validating: 0it [00:00, ?it/s]
# Validating: 0it [00:00, ?it/s]
# Validating: 0it [00:00, ?it/s]
# Validating: 0it [00:00, ?it/s]
# Validating: 0it [00:00, ?it/s]
# Validating: 0it [00:00, ?it/s]
# Validating: 0it [00:00, ?it/s]
# Validating: 0it [00:00, ?it/s]
# Validating: 0it [00:00, ?it/s]
# Validating: 0it [00:00, ?it/s]
# Validating: 0it [00:00, ?it/s]
# Validating: 0it [00:00, ?it/s]
# Validating: 0it [00:00, ?it/s]
# Validating: 0it [00:00, ?it/s]
# Validating: 0it [00:00, ?it/s]
# Validating: 0it [00:00, ?it/s]
# Validating: 0it [00:00, ?it/s]
# Validating: 0it [00:00, ?it/s]
# Validating: 0it [00:00, ?it/s]
# Validating: 0it [00:00, ?it/s]
# /Users/george/opt/anaconda3/envs/pl2/lib/python3.6/site-packages/SBCMP/__init__.py:25: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   return(xx/xx.sum(axis=1)[:, np.newaxis] )
# /Users/george/opt/anaconda3/envs/pl2/lib/python3.6/site-packages/SBCMP/__init__.py:25: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   return(xx/xx.sum(axis=1)[:, np.newaxis] )
# [0.5267249757045676, 0.3135483870967742, 0.44235588972431084, 0.3365384615384615, 0.4666666666666667, 0.4946236559139785] [0.631681243926142, 0.6864516129032258, 0.8646616541353384, 0.7307692307692307, 0.8407407407407407, 0.7168458781362006] [0.5267249757045677, 0.6154838709677419, 0.5087719298245613, 0.5705128205128205, 0.7518518518518519, 0.4193548387096774] [0.5174927113702624, 0.5393548387096774, 0.6303258145363408, 0.5785256410256411, 0.45925925925925926, 0.4551971326164875] [0.48833819241982507, 0.7625806451612903, 0.7268170426065164, 0.6025641025641025, 0.5518518518518519, 0.6917562724014337] [0.5578231292517006, 0.47870967741935483, 0.6027568922305764, 0.43269230769230765, 0.5703703703703704, 0.5268817204301075] [0.5053449951409135, 0.35161290322580646, 0.41102756892230574, 0.35256410256410253, 0.6388888888888888, 0.6057347670250897] [0.5218658892128281, 0.664516129032258, 0.5, 0.5304487179487178, 0.7851851851851852, 0.5]
# /Users/george/opt/anaconda3/envs/pl2/lib/python3.6/site-packages/pytorch_lightning/trainer/connectors/callback_connector.py:168: LightningDeprecationWarning: Setting `Trainer(weights_summary=None)` is deprecated in v1.5 and will be removed in v1.7. Please set `Trainer(enable_model_summary=False)` instead.
#   "Setting `Trainer(weights_summary=None)` is deprecated in v1.5 and will be removed"
# GPU available: False, used: False
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# Validation sanity check: 0it [00:00, ?it/s]
# /Users/george/opt/anaconda3/envs/pl2/lib/python3.6/site-packages/pytorch_lightning/trainer/data_loading.py:133: UserWarning: The dataloader, val_dataloader 0, does not have many workers which may be a bottleneck. Consider increasing the value of the `num_workers` argument` (try 8 which is the number of cpus on this machine) in the `DataLoader` init to improve performance.
#   f"The dataloader, {name}, does not have many workers which may be a bottleneck."
# /Users/george/opt/anaconda3/envs/pl2/lib/python3.6/site-packages/SBCMP/__init__.py:78: UserWarning: Implicit dimension choice for softmax has been deprecated. Change the call to include dim=X as an argument.
#   y_hat = softmax(x)
# /Users/george/opt/anaconda3/envs/pl2/lib/python3.6/site-packages/pytorch_lightning/trainer/data_loading.py:133: UserWarning: The dataloader, train_dataloader, does not have many workers which may be a bottleneck. Consider increasing the value of the `num_workers` argument` (try 8 which is the number of cpus on this machine) in the `DataLoader` init to improve performance.
#   f"The dataloader, {name}, does not have many workers which may be a bottleneck."
# Training: 0it [00:00, ?it/s]
# Validating: 0it [00:00, ?it/s]
# Validating: 0it [00:00, ?it/s]
# Validating: 0it [00:00, ?it/s]
# Validating: 0it [00:00, ?it/s]
# Validating: 0it [00:00, ?it/s]
# Validating: 0it [00:00, ?it/s]
# Validating: 0it [00:00, ?it/s]
# Validating: 0it [00:00, ?it/s]
# Validating: 0it [00:00, ?it/s]
# Validating: 0it [00:00, ?it/s]
# Validating: 0it [00:00, ?it/s]
# Validating: 0it [00:00, ?it/s]
# Validating: 0it [00:00, ?it/s]
# Validating: 0it [00:00, ?it/s]
# Validating: 0it [00:00, ?it/s]
# Validating: 0it [00:00, ?it/s]
# Validating: 0it [00:00, ?it/s]
# Validating: 0it [00:00, ?it/s]
# Validating: 0it [00:00, ?it/s]
# Validating: 0it [00:00, ?it/s]
# Validating: 0it [00:00, ?it/s]
# Validating: 0it [00:00, ?it/s]
# Validating: 0it [00:00, ?it/s]

# %%
results_dict=v_out

# %%
def flatten(l):
    return [item for sublist in l for item in sublist]

# %%
studies = pd.concat([md.Study, df_with_batch[0]], axis=1).drop_duplicates().sort_values(0)
    
print(results_dict)

summary_auroc_df = pd.DataFrame({'auROC': flatten( [b for a,b in \
                                                   results_dict['aurocs'].items()] ), 
                                 'Group': flatten( [ [a]*len( results_dict['aurocs']['linear'])
                                                  for a in results_dict['aurocs']]),
                                 'auPR': flatten( [b for a,b in \
                                                   results_dict['auprs'].items()] ),
                                })

studies = pd.concat([md.Study, df_with_batch[0]], axis=1).drop_duplicates()\
                    .sort_values(0).reset_index()
summary_auroc_df = pd.concat([summary_auroc_df, 
                                  studies], 
                                  axis=1
                                )

# save the boxplot
plotting.produce_auroc_boxplot(summary_auroc_df,
            out_path='auroc-boxplot-linear-hiv-with-age.pdf', 
                              sig_dict=results_dict['is_sig']
                              )
# Out:
# No handles with labels found to put in legend.
# {'models': {'linear': [[StandardScaler(), LogisticRegression(max_iter=25000, penalty='none')], [StandardScaler(), LogisticRegression(max_iter=25000, penalty='none')], [StandardScaler(), LogisticRegression(max_iter=25000, penalty='none')], [StandardScaler(), LogisticRegression(max_iter=25000, penalty='none')], [StandardScaler(), LogisticRegression(max_iter=25000, penalty='none')], [StandardScaler(), LogisticRegression(max_iter=25000, penalty='none')], [StandardScaler(), LogisticRegression(max_iter=25000, penalty='none')], [StandardScaler(), LogisticRegression(max_iter=25000, penalty='none')], [StandardScaler(), LogisticRegression(max_iter=25000, penalty='none')], [StandardScaler(), LogisticRegression(max_iter=25000, penalty='none')], [StandardScaler(), LogisticRegression(max_iter=25000, penalty='none')], [StandardScaler(), LogisticRegression(max_iter=25000, penalty='none')], [StandardScaler(), LogisticRegression(max_iter=25000, penalty='none')], [StandardScaler(), LogisticRegression(max_iter=25000, penalty='none')], [StandardScaler(), LogisticRegression(max_iter=25000, penalty='none')]], 'debias-m': [PL_SBCMP(
#   (linear): Linear(in_features=779, out_features=2, bias=True)
# ), PL_SBCMP(
#   (linear): Linear(in_features=779, out_features=2, bias=True)
# ), PL_SBCMP(
#   (linear): Linear(in_features=779, out_features=2, bias=True)
# ), PL_SBCMP(
#   (linear): Linear(in_features=779, out_features=2, bias=True)
# ), PL_SBCMP(
#   (linear): Linear(in_features=779, out_features=2, bias=True)
# ), PL_SBCMP(
#   (linear): Linear(in_features=779, out_features=2, bias=True)
# ), PL_SBCMP(
#   (linear): Linear(in_features=779, out_features=2, bias=True)
# ), PL_SBCMP(
#   (linear): Linear(in_features=779, out_features=2, bias=True)
# ), PL_SBCMP(
#   (linear): Linear(in_features=779, out_features=2, bias=True)
# ), PL_SBCMP(
#   (linear): Linear(in_features=779, out_features=2, bias=True)
# ), PL_SBCMP(
#   (linear): Linear(in_features=779, out_features=2, bias=True)
# ), PL_SBCMP(
#   (linear): Linear(in_features=779, out_features=2, bias=True)
# ), PL_SBCMP(
#   (linear): Linear(in_features=779, out_features=2, bias=True)
# ), PL_SBCMP(
#   (linear): Linear(in_features=779, out_features=2, bias=True)
# ), PL_SBCMP(
#   (linear): Linear(in_features=779, out_features=2, bias=True)
# )], 'combat': [[StandardScaler(), LogisticRegression(max_iter=25000, penalty='none')], [StandardScaler(), LogisticRegression(max_iter=25000, penalty='none')], [StandardScaler(), LogisticRegression(max_iter=25000, penalty='none')], [StandardScaler(), LogisticRegression(max_iter=25000, penalty='none')], [StandardScaler(), LogisticRegression(max_iter=25000, penalty='none')], [StandardScaler(), LogisticRegression(max_iter=25000, penalty='none')], [StandardScaler(), LogisticRegression(max_iter=25000, penalty='none')], [StandardScaler(), LogisticRegression(max_iter=25000, penalty='none')], [StandardScaler(), LogisticRegression(max_iter=25000, penalty='none')], [StandardScaler(), LogisticRegression(max_iter=25000, penalty='none')], [StandardScaler(), LogisticRegression(max_iter=25000, penalty='none')], [StandardScaler(), LogisticRegression(max_iter=25000, penalty='none')], [StandardScaler(), LogisticRegression(max_iter=25000, penalty='none')], [StandardScaler(), LogisticRegression(max_iter=25000, penalty='none')], [StandardScaler(), LogisticRegression(max_iter=25000, penalty='none')]], 'conqur': [[StandardScaler(), LogisticRegression(max_iter=25000, penalty='none')], [StandardScaler(), LogisticRegression(max_iter=25000, penalty='none')], [StandardScaler(), LogisticRegression(max_iter=25000, penalty='none')], [StandardScaler(), LogisticRegression(max_iter=25000, penalty='none')], [StandardScaler(), LogisticRegression(max_iter=25000, penalty='none')], [StandardScaler(), LogisticRegression(max_iter=25000, penalty='none')], [StandardScaler(), LogisticRegression(max_iter=25000, penalty='none')], [StandardScaler(), LogisticRegression(max_iter=25000, penalty='none')], [StandardScaler(), LogisticRegression(max_iter=25000, penalty='none')], [StandardScaler(), LogisticRegression(max_iter=25000, penalty='none')], [StandardScaler(), LogisticRegression(max_iter=25000, penalty='none')], [StandardScaler(), LogisticRegression(max_iter=25000, penalty='none')], [StandardScaler(), LogisticRegression(max_iter=25000, penalty='none')], [StandardScaler(), LogisticRegression(max_iter=25000, penalty='none')], [StandardScaler(), LogisticRegression(max_iter=25000, penalty='none')]], 'snm': [[StandardScaler(), LogisticRegression(max_iter=25000, penalty='none')], [StandardScaler(), LogisticRegression(max_iter=25000, penalty='none')], [StandardScaler(), LogisticRegression(max_iter=25000, penalty='none')], [StandardScaler(), LogisticRegression(max_iter=25000, penalty='none')], [StandardScaler(), LogisticRegression(max_iter=25000, penalty='none')], [StandardScaler(), LogisticRegression(max_iter=25000, penalty='none')], [StandardScaler(), LogisticRegression(max_iter=25000, penalty='none')], [StandardScaler(), LogisticRegression(max_iter=25000, penalty='none')], [StandardScaler(), LogisticRegression(max_iter=25000, penalty='none')], [StandardScaler(), LogisticRegression(max_iter=25000, penalty='none')], [StandardScaler(), LogisticRegression(max_iter=25000, penalty='none')], [StandardScaler(), LogisticRegression(max_iter=25000, penalty='none')], [StandardScaler(), LogisticRegression(max_iter=25000, penalty='none')], [StandardScaler(), LogisticRegression(max_iter=25000, penalty='none')], [StandardScaler(), LogisticRegression(max_iter=25000, penalty='none')]], 'mmuphin': [[StandardScaler(), LogisticRegression(max_iter=25000, penalty='none')], [StandardScaler(), LogisticRegression(max_iter=25000, penalty='none')], [StandardScaler(), LogisticRegression(max_iter=25000, penalty='none')], [StandardScaler(), LogisticRegression(max_iter=25000, penalty='none')], [StandardScaler(), LogisticRegression(max_iter=25000, penalty='none')], [StandardScaler(), LogisticRegression(max_iter=25000, penalty='none')], [StandardScaler(), LogisticRegression(max_iter=25000, penalty='none')], [StandardScaler(), LogisticRegression(max_iter=25000, penalty='none')], [StandardScaler(), LogisticRegression(max_iter=25000, penalty='none')], [StandardScaler(), LogisticRegression(max_iter=25000, penalty=' ...

# %%
sns.set_theme()

# %%
pd.read_csv('../../New-vaginal-project/numom_preeclampsia/results/immune-factor-associations/')

# %%
sns.set()
# Out:
# <module 'seaborn' from '/Users/george/opt/anaconda3/envs/pl2/lib/python3.6/site-packages/seaborn/__init__.py'>

# %%
# save the boxplot
plotting.produce_auroc_boxplot(summary_auroc_df,
                               out_path='auroc-boxplot-linear-hiv-with-age.pdf', 
                               sig_dict=results_dict['is_sig'], 
                               hide_axes=False
                               )
# Out:
# No handles with labels found to put in legend.

# %%
plotitng.

# %%
run_predictions(y, 
                df_with_batch, 
                df_conqur, 
                df_combat, 
                seed=123, 
                do_clr_transform=False,
                b_str=batch_weight_feature_and_nbatchpairs_scaling(1e4, df_with_batch),
                df_snm=df_snm, 
                df_mup=df_mup, 
                df_pls=df_pls, 
                df_perc=df_perc
                )

# %%
df_
# Out:
#         auROC     Group
# 0    0.757937  percnorm
# 1    0.368254  percnorm
# 2    0.689032  percnorm
# 3    0.605769  percnorm
# 4    0.430082  percnorm
# ..        ...       ...
# 97   0.454545      voom
# 98   0.652482      voom
# 99   0.488824      voom
# 100       NaN      voom
# 101  0.622360      voom
#
# [102 rows x 2 columns]

# %%
res=pd.read_csv('hiv-age-results.csv', index_col=0).dropna() ## NAs are from the study w/ all positives
df_ = pd.read_csv('hiv-age-results-all.csv', index_col=0).dropna()

# %%
df= pd.concat([res.loc[res.Group.isin(['Linear', 'DEBIAS-M'])], 
               df_])

# %%
df['Group']=df.Group.str.lower().str.replace('plsdabatch', 
                                             'plsda', 
                                             regex=False).str.replace('voom', 'snm')

# %%
df.Group\
    .unique()
# Out:
# array(['linear', 'debias-m', 'percnorm', 'combat', 'conqur', 'mmuphin',
#        'plsda', 'snm'], dtype=object)

# %%
order=[
#        'linear', 
#        'combat', 
       'conqur', 
       'percnorm',
       'snm',
#        'mmuphin',
#        'plsda',
#        'debias-m'
       ]

# %%
data=df.copy()

# %%
data2=pd.read_csv('../results/HIVRC/auroc-boxplot-linear.csv', 
                 index_col=0
                 )

# %%
data['Covariate']='Age'

# %%
data2['Covariate']='Gender'

# %%
data_ = pd.concat([data[['auROC', 'Group', 'Covariate']], 
                   data2[['auROC', 'Group', 'Covariate']]
                  ]).reset_index(drop=True)

# %%
data_['Covariate_'] = data_['Group'] + ' ' + data_['Covariate']

# %%
global_palette['conqur Age'] = global_palette['conqur']
global_palette['percnorm Age'] = global_palette['percnorm']
global_palette['snm Age'] = global_palette['snm']
global_palette['conqur Gender'] = global_palette['conqur']
global_palette['percnorm Gender'] = global_palette['percnorm']
global_palette['snm Gender'] = global_palette['snm']

# %%
data_ = data_.loc[data_['Group'].isin(order)]

# %%
from matplotlib import pyplot as plt
from matplotlib.legend_handler import HandlerTuple
from matplotlib.patches import PathPatch
from matplotlib.colors import to_rgb
import seaborn as sns
import pandas as pd
import numpy as np

np.random.seed(20230215)
order = ['Ash1', 'E1A', 'FUS', 'p53']
colors = ['gold', 'teal', 'darkorange', 'royalblue']
hue_order = ['A', 'B']

df_idrs = pd.DataFrame({'construct': np.repeat(order, 200),
                        'Norm_Ef_IDR/Ef_GS': (np.random.normal(0.03, 1, 800).cumsum() + 10) / 15,
                        'location': np.tile(np.repeat(hue_order, 100), 4)})
fig, ax = plt.subplots(figsize=(12, 5))

sns.boxplot(data=df_idrs, x=df_idrs['construct'], y=df_idrs['Norm_Ef_IDR/Ef_GS'], hue='location',
            order=order, hue_order=hue_order, ax=ax)
box_colors = [f + (1 - f) * np.array(to_rgb(c))  # whiten colors depending on hue
              for c in colors for f in np.linspace(0, 0.5, len(hue_order))]
box_patches = [p for p in ax.patches if isinstance(p, PathPatch)]
for patch, color in zip(box_patches, box_colors):
    patch.set_facecolor(color)

sns.stripplot(y='Norm_Ef_IDR/Ef_GS', x='construct', data=df_idrs, hue=df_idrs['location'],
              jitter=0.4, marker='o', alpha=0.4, edgecolor='black', linewidth=1, dodge=True, ax=ax)
for collection, color in zip(ax.collections, box_colors):
    collection.set_facecolor(color)

ax.axhline(y=1, linestyle='--', color='black', linewidth=2)
handles = [tuple(box_patches[i::len(hue_order)]) for i in range(len(hue_order))]
# ax.legend(handles=handles, labels=hue_order, title='hue category',
#           handlelength=4, handler_map={tuple: HandlerTuple(ndivide=None, pad=0)},
#           loc='upper left', bbox_to_anchor=(1.01, 1))
plt.tight_layout()
plt.show()

# %%
data_.Covariate_.unique()

# %%
order_ = data_.Covariate_.unique()[[3,1,5,0,4,2]]

# %%
from scipy.stats import wilcoxon
def wilcox_test(df):
    unique_covs=df.Covariate_.unique()
    return( 
        wilcoxon(df.loc[df.Covariate_==unique_covs[0]].auROC, 
                 df.loc[df.Covariate_==unique_covs[1]].auROC)
          )

# %%
# Out:
# {'percnorm': WilcoxonResult(statistic=39.0, pvalue=0.39672623294506304),
#  'conqur': WilcoxonResult(statistic=47.0, pvalue=0.48870849609375),
#  'snm': WilcoxonResult(statistic=31.0, pvalue=0.10699462890625)}

# %%
a
# Out:
# array(['percnorm', 'conqur', 'snm'], dtype=object)

# %%
plt.subplots(1,
                 figsize=(8, 10),
                 dpi=500)

ax=sns.boxplot(#x='Group', 
               y='auROC', 
               x='Covariate_',
               data=data_, 
               order=order_,
#                hue_order = order,
               palette=global_palette,
               width=.75,
               fliersize=0
           )

handles, labels = ax.get_legend_handles_labels()

sns.stripplot(#x='Group', 
              y='auROC', 
              x='Covariate_',
              data=data_,
              order=order_,
#               hue_order = order,
              dodge=True,
              ax=ax, 
              size=10, 
              color='k'
              )
# Put the legend out of the figure
 
# plt.legend(bbox_to_anchor=(1.01, .7), loc=2, borderaxespad=0.)
plt.legend().remove()
ax.set_title(None)
ax.yaxis.set_major_locator(ticker.MultipleLocator(0.05))
plt.ylim(0.25, 1.05)
plt.xticks(rotation=90)
ax.set( yticks=[0.3,0.5,0.7, 0.9] )
plt.savefig('../results/covariate-selection/hiv-age-or-gender.pdf',
            dpi=900, 
            bbox_inches='tight',
            format='pdf')
plt.show()
# Out:
# No handles with labels found to put in legend.

# %%
{a:wilcox_test( data_.loc[data_.Group == a] )
    for a in data_.Group.unique()}
# Out:
# {'percnorm': WilcoxonResult(statistic=39.0, pvalue=0.39672623294506304),
#  'conqur': WilcoxonResult(statistic=47.0, pvalue=0.48870849609375),
#  'snm': WilcoxonResult(statistic=31.0, pvalue=0.10699462890625)}

# %%
data=pd.read_csv('../results/HIVRC/auroc-boxplot-linear.csv', 
                 index_col=0
                 )
plt.subplots(1,
                 figsize=(4, 10),
                 dpi=500)

ax=sns.boxplot(x='Group', 
               y='auROC', 
               data=data, 
               order=order,
               hue_order = order,
               palette=global_palette,
               width=.75,
               fliersize=0
           )

handles, labels = ax.get_legend_handles_labels()

sns.stripplot(x='Group', 
              y='auROC', 
              data=data,
              order=order,
              hue_order = order,
              dodge=True,
              ax=ax, 
              size=10, 
              color='k'
           )
# Put the legend out of the figure
plt.legend(bbox_to_anchor=(1.01, .7), loc=2, borderaxespad=0.)
ax.set_title(None)
ax.yaxis.set_major_locator(ticker.MultipleLocator(0.05))
plt.ylim(0.25, 1.05)
plt.xticks(rotation=90)
ax.set( yticks=[0.3,0.5,0.7, 0.9] )
plt.savefig('../results/covariate-selection/hiv-gender.pdf',
            dpi=900, 
            bbox_inches='tight',
            format='pdf')
plt.show()
# Out:
# No handles with labels found to put in legend.

# %%
plt.subplots(1,
                 figsize=(11.02, 10),
                 dpi=500)

ax=sns.boxplot(x='Group', 
               y='auROC', 
               data=data, 
               order=order,
               hue_order = order,
               palette=global_palette,
               width=.75,
               fliersize=0
           )

handles, labels = ax.get_legend_handles_labels()

sns.stripplot(x='Group', 
              y='auROC', 
              data=data,
              order=order,
              hue_order = order,
              dodge=True,
              ax=ax, 
              size=10, 
              color='k'
           )
# Put the legend out of the figure
plt.legend(bbox_to_anchor=(1.01, .7), loc=2, borderaxespad=0.)
ax.set_title(None)
ax.yaxis.set_major_locator(ticker.MultipleLocator(0.05))
plt.ylim(0.25, 1.05)
plt.xticks(rotation=90)
ax.set( yticks=[0.3,0.5,0.7, 0.9] )
plt.show()
# Out:
# No handles with labels found to put in legend.

# %%
res.dropna()
# Out:
#        auROC     Group
# 0   0.615079      voom
# 1   0.492063      voom
# 2   0.809032      voom
# 3   0.641026      voom
# 4   0.395613      voom
# 5   0.769424      voom
# 6   0.604789      voom
# 7   0.727599      voom
# 8   0.532007      voom
# 10  0.675758      voom
# 11  0.714815      voom
# 12  0.454545      voom
# 13  0.652482      voom
# 14  0.488824      voom
# 16  0.622360      voom
# 17  0.531746    Linear
# 18  0.761905  DEBIAS-M
# 19  0.576190    Linear
# 20  0.676190  DEBIAS-M
# 21  0.450968    Linear
# 22  0.700645  DEBIAS-M
# 23  0.592949    Linear
# 24  0.717949  DEBIAS-M
# 25  0.536232    Linear
# 26  0.513514  DEBIAS-M
# 27  0.548872    Linear
# 28  0.857143  DEBIAS-M
# 29  0.707213    Linear
# 30  0.554685  DEBIAS-M
# 31  0.473118    Linear
# 32  0.691756  DEBIAS-M
# 33  0.520473    Linear
# 34  0.474337  DEBIAS-M
# 35  0.587879    Linear
# 36  0.821212  DEBIAS-M
# 37  0.600000    Linear
# 38  0.818519  DEBIAS-M
# 39  0.227273    Linear
# 40  0.681818  DEBIAS-M
# 41  0.541844    Linear
# 42  0.551773  DEBIAS-M
# 43  0.631681    Linear
# 44  0.635569  DEBIAS-M
# 45  0.664596    Linear
# 46  0.688199  DEBIAS-M
